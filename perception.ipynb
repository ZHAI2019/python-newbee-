# %%
# 首先把groupA的表格合并 
import pandas as pd
import os
Folder_Path = r"D:\jupy nt\2019_6_datahomework\perception"          #要拼接的文件夹及其完整路径，注意不要包含中文
SaveFile_Path =  r"D:\jupy nt\2019_6_datahomework\all"       #拼接后要保存的文件路径
SaveFile_Name = r"all_perception.csv"              #合并后要保存的文件名

#修改当前工作目录
os.chdir(Folder_Path)
#将该文件夹下的所有文件名存入一个列表
file_list = os.listdir()

#读取第一个CSV文件并包含表头
df = pd.read_csv(Folder_Path +'\\'+ file_list[0])   #编码默认UTF-8，若乱码自行更改

#将读取的第一个CSV文件写入合并后的文件保存
df.to_csv(SaveFile_Path+'\\'+ SaveFile_Name,encoding="utf_8_sig",index=False)

#循环遍历列表中各个CSV文件名，并追加到合并后的文件
for i in range(1,len(file_list)):
    df = pd.read_csv(Folder_Path + '\\'+ file_list[i])
    df.to_csv(SaveFile_Path+'\\'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv(r"D:\jupy nt\2019_6_datahomework\all\all_perception.csv")
df = pd.DataFrame(df)
df = df.drop(["key_resp_2.keys","key_resp_2.rt","key_resp_6.keys","key_resp_6.rt"],axis = 1)
df = df.dropna()



n = 32
corr_mean = df["trials.response"].mean()

# corr_std =  df["trials.response"].std()
# corr_se = corr_std/np.sqrt(n-1)

# plt.xlim(0,5)
# x=2.5
# plt.title("perception %correct")
# plt.xticks([])
# plt.ylabel("%correct")
# plt.bar(x,corr_mean,yerr = corr_se,width = 1,alpha=0.7,error_kw = {'ecolor' : 'grey', 'capsize' :5})
# plt.savefig(r"D:\jupy nt\2019_6_datahomework\all\f1.png")

# print(corr_mean)
 

# g_1 = df.groupby(["trials.response"])
# conf_cor = g_1["key_resp_4.keys"].mean()
# conf_cor_std = g_1["key_resp_4.keys"].std()
# conf_cor_se = conf_cor_std/np.sqrt(n-1)
# x = np.array([0.25,0.75])
# y = list(conf_cor)
# e = list(conf_cor_se)
# plt.xlim(0,1)
# plt.xticks((0.25,0.75),["incorrect","correct"])
# plt.title("perception conf×inc/cor")
# plt.bar(x,y,yerr = e,alpha=0.7,width = 0.2,error_kw = {'ecolor' : 'grey', 'capsize' :5}) 
# plt.ylabel("conf mean")
# plt.savefig(r"D:\jupy nt\2019_6_datahomework\all\f2.png")


# df.head()
# g_2 = df.groupby(["Sex"])
# corr_sex_m = g_2["trials.response"].mean()
# corr_sex_st = g_2["trials.response"].std()
# corr_sex_se = corr_sex_st/np.sqrt(n-1)
# # print(corr_sex_m ,corr_sex_st,corr_sex_se)
# x1=([0.25,0.75])
# y1 = list(corr_sex_m)
# e1 = list(corr_sex_se)
# plt.title("%correct × Sex ")
# plt.xlim(0,1)
# plt.xticks((0.25,0.75),["Female","Male"])
# plt.bar(x1,y1,yerr = e1,alpha=0.7,width = 0.2,error_kw = {'ecolor' : 'grey', 'capsize' :5}) 
# plt.ylabel("%correct")
# plt.savefig(r"D:\jupy nt\2019_6_datahomework\all\f3.png")


# g_3 = df.groupby(["subject"])
# corr_sub_m = g_3["trials.response"].mean()
# corr_sub_se = g_3["trials.response"].std()/np.sqrt(n-1)
df2= pd.read_csv(r"D:\jupy nt\2019_6_datahomework\all\1.csv")
df2 = pd.DataFrame(df2)
# df2.head()
# g_4 = df2.groupby(["a"])
# corr_age_m =g_4["m"].mean()
# corr_age_se = g_4["m"].std()/np.sqrt(n-1)
# x= range(1,12,2)
# y = list(corr_age_m)
# e = list(corr_age_se)
# e[5] = 0
# plt.title("%correct × Age")
# plt.xlim(0,12)
# plt.ylim(0,1)
# plt.xticks((1,3,5,7,9,11),["21-30","31-40","41-50","51-60","61-70","≥71"],)
# plt.xlabel("Age")
# plt.ylabel("%correct")
# plt.bar(x,y,yerr = e ,alpha=0.7,width = 1,error_kw = {'ecolor' : 'grey', 'capsize' :1})
# plt.savefig(r"D:\jupy nt\2019_6_datahomework\all\f4.png")



g_5 = df2.groupby(["e"])
corr_edu_m =g_5["m"].mean()
corr_edu_se = g_5["m"].std()/np.sqrt(n-1)
print(corr_edu_m,corr_edu_se)
x= range(1,8,2)
y = list(corr_edu_m)
e = list(corr_edu_se)
plt.title("%correct × Edu level")
plt.xlim(0,8)
plt.ylim(0,1)
plt.xticks((1,3,5,7),["6-9","10-12","13-16","≥16"])
plt.xlabel("edu level/year")
plt.ylabel("%correct")
plt.bar(x,y,yerr = e ,alpha=0.7,width = 1,error_kw = {'ecolor' : 'grey', 'capsize' :1})
plt.savefig(r"D:\jupy nt\2019_6_datahomework\all\f5.png")
# # plt.show()
# Out:
# e
# 3    0.687500
# 4    0.663194
# 5    0.697531
# 6    0.704861
# Name: m, dtype: float64 e
# 3    0.001592
# 4    0.010249
# 5    0.002490
# 6    0.001873
# Name: m, dtype: float64
